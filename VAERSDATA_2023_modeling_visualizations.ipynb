# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
VAERSDATA_2023_with_SYMPTOMS_df_sample_cleaned = pd.read_csv('VAERSDATA_2023_with_SYMPTOMS_df_sample_cleaned.csv')

# %%
VAERSDATA_2023_with_SYMPTOMS_df_sample_cleaned[VAERSDATA_2023_with_SYMPTOMS_df_sample_cleaned.columns[2:]].sum()
# Out:
# Product storage error               4335
# COVID-19                            3601
# No adverse event                    3451
# SARS-CoV-2 test positive            2237
# Expired product administered        1717
#                                     ...
# Sepsis                               106
# Loss of consciousness                105
# Swelling                             103
# Sneezing                             103
# Incomplete course of vaccination     102
# Length: 112, dtype: int64

# %%
VAERSDATA_2023_with_SYMPTOMS_df_sample_cleaned_counts = VAERSDATA_2023_with_SYMPTOMS_df_sample_cleaned[VAERSDATA_2023_with_SYMPTOMS_df_sample_cleaned.columns[2:]].sum()

# %%
x = VAERSDATA_2023_with_SYMPTOMS_df_sample_cleaned_counts.index
y = VAERSDATA_2023_with_SYMPTOMS_df_sample_cleaned_counts.values

fig, ax = plt.subplots()

ax.barh(x, y)

fig.set_size_inches(35, 28)

plt.show()
